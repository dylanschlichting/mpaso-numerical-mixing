# %%
import os
import xarray as xr
import numpy as np
import netCDF4 as nc
import argparse
import datetime
import numpy as np
import subprocess

# %%
# Horizontal resolutions (len-edges). Split into sub and super km for 
# managine I/O on login node. Could need compute node for 100- and 200-m. 
# hres = np.array([100, 200, 300, 400, 500, 600, 700, 800, 900, 1000])
hres = np.array([500, 600, 700, 800, 900, 1000])
# hres = np.array([1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000])
# hres = np.array([10000])
y_len = 100000  # along-channel distance in meters

# Loop through each resolution
for h in hres:
    num_x = y_len / h
    num_x = np.ceil(num_x)  # round up

    num_y = 2 * np.sqrt(3) * num_x
    num_y = int(np.ceil(num_y))
    if num_y % 2 != 0:
        num_y += 1 # make divisible by 2

    case_name = f"dx{int(h)}m"

    cmd = [
        "python", "channel_case.py",
        f"--case-name=channel_{h}m_50_layers",
        f"--num-xcell={int(num_x)}",
        f"--num-ycell={int(num_y)}",
        f"--len-edges={int(h)}",
        "--num-layer=50",
        "--wind-stress=0.1"
    ]

    print(f"Running: {case_name} with xcells={num_x}, ycells={num_y}")
    subprocess.run(cmd)
# Out:
# Running: dx500m with xcells=200.0, ycells=694
#
#
# cullCell
# int32
# Running: MpasCellCuller.x /tmp/tmpf2gwln4n/ds_in.nc /tmp/tmpf2gwln4n/ds_out.nc
#
#
# ************************************************************
# MPAS_CELL_CULLER:
#   C++ version
#   Remove cells/edges/vertices from a NetCDF MPAS Mesh file.
#
#
#   Compiled on Jul 31 2024 at 09:14:14.
# ************************************************************
#
#
# Reading input grid.
# Read dimensions:
#     nCells = 139200
#     nVertices = 278400
#     nEdges = 417600
#     vertexDegree = 3
#     maxEdges = 6
#     Spherical? = 0
#     Periodic? = 1
#     x_period = 100000
#     y_period = 0
# Marking cells for removal.
# Removing 400 cells.
# Marking vertices for removal.
# Removing 400 vertices.
# Marking edges for removal.
# Removing 800 edges.
# Writing grid dimensions
# Writing grid attributes
# Writing grid coordinates
# Mapping and writing cell fields and culled_graph.info
# Mapping and writing edge fields
# ...

# %% [markdown]
# ### Now change this for 75 and 100 layers

# %%
# Horizontal resolutions (len-edges)
hres = np.array([100, 200, 300, 400, 500, 600, 700, 800, 900])
# hres = np.array([1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000])
y_len = 100000  # along-channel distance in meters

# Loop through each resolution
for h in hres:
    num_x = y_len / h
    num_x = np.ceil(num_x)  # round up

    num_y = 2 * np.sqrt(3) * num_x
    num_y = int(np.ceil(num_y))
    if num_y % 2 != 0:
        num_y += 1 # make divisible by 2

    case_name = f"dx{int(h)}m"

    cmd = [
        "python", "channel_case.py",
        f"--case-name=channel_{h}m_75_layers",
        f"--num-xcell={int(num_x)}",
        f"--num-ycell={int(num_y)}",
        f"--len-edges={int(h)}",
        "--num-layer=75",
        "--wind-stress=0.1"
    ]

    print(f"Running: {case_name} with xcells={num_x}, ycells={num_y}")
    subprocess.run(cmd)
# Out:
# Running: dx100m with xcells=1000.0, ycells=3466

# %%
# Horizontal resolutions (len-edges)
# hres = np.array([100, 200, 300, 400, 500, 600, 700, 800, 900])
hres = np.array([500, 600, 700, 800, 900])
# hres = np.array([1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000])
y_len = 100000  # along-channel distance in meters

# Loop through each resolution
for h in hres:
    num_x = y_len / h
    num_x = np.ceil(num_x)  # round up

    num_y = 2 * np.sqrt(3) * num_x
    num_y = int(np.ceil(num_y))
    if num_y % 2 != 0:
        num_y += 1 # make divisible by 2

    case_name = f"dx{int(h)}m"

    cmd = [
        "python", "channel_case.py",
        f"--case-name=channel_{h}m_100_layers",
        f"--num-xcell={int(num_x)}",
        f"--num-ycell={int(num_y)}",
        f"--len-edges={int(h)}",
        "--num-layer=100",
        "--wind-stress=0.1"
    ]

    print(f"Running: {case_name} with xcells={num_x}, ycells={num_y}")
    subprocess.run(cmd)
# Out:
# Running: dx500m with xcells=200.0, ycells=694
# Running: dx600m with xcells=167.0, ycells=580
# Running: dx700m with xcells=143.0, ycells=496
# Running: dx800m with xcells=125.0, ycells=434
# Running: dx900m with xcells=112.0, ycells=388
# Traceback (most recent call last):
#   File "channel_case.py", line 2, in <module>
#     import xarray as xr
# ImportError: No module named xarray
# Traceback (most recent call last):
#   File "channel_case.py", line 2, in <module>
#     import xarray as xr
# ImportError: No module named xarray
# Traceback (most recent call last):
#   File "channel_case.py", line 2, in <module>
#     import xarray as xr
# ImportError: No module named xarray
# Traceback (most recent call last):
#   File "channel_case.py", line 2, in <module>
#     import xarray as xr
# ImportError: No module named xarray
# Traceback (most recent call last):
#   File "channel_case.py", line 2, in <module>
#     import xarray as xr
# ImportError: No module named xarray

# %%
hres = np.array([100, 200, 300, 400, 500, 600, 700, 800, 900,
1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000])
# Harmonic viscosity
del2 = 33.3*(hres/30000)
print('del2', del2) 

# Biharmonic viscosity
del4 = 3.33*10**11*(hres/30000)**3
print('del4', del4)

# Baroclinic DT, ~proportional to hres
dt = 0.06*hres
print('baroclinic dt', dt)
# Assume 20 subcycles for barotropic
btr_dt = dt/20
print('barotropic dt', btr_dt)
# Out:
# del2 [ 0.111  0.222  0.333  0.444  0.555  0.666  0.777  0.888  0.999  1.11
#   2.22   3.33   4.44   5.55   6.66   7.77   8.88   9.99  11.1  ]
# del4 [1.23333333e+04 9.86666667e+04 3.33000000e+05 7.89333333e+05
#  1.54166667e+06 2.66400000e+06 4.23033333e+06 6.31466667e+06
#  8.99100000e+06 1.23333333e+07 9.86666667e+07 3.33000000e+08
#  7.89333333e+08 1.54166667e+09 2.66400000e+09 4.23033333e+09
#  6.31466667e+09 8.99100000e+09 1.23333333e+10]
# baroclinic dt [  6.  12.  18.  24.  30.  36.  42.  48.  54.  60. 120. 180. 240. 300.
#  360. 420. 480. 540. 600.]
# barotropic dt [ 0.3  0.6  0.9  1.2  1.5  1.8  2.1  2.4  2.7  3.   6.   9.  12.  15.
#  18.  21.  24.  27.  30. ]

# %% [markdown]
# ### List of srun commands
# srun -n 128 ./ocean_model -n namelist_10000m_50_layers.ocean -s streams_10000m_50_layers.ocean
# srun -n 128 ./ocean_model -n namelist_10000m_100_layers.ocean -s streams_10000m_100_layers.ocean
#
# srun -n 256 ./ocean_model -n namelist_9000m_50_layers.ocean -s streams_9000m_50_layers.ocean
# srun -n 256 ./ocean_model -n namelist_9000m_100_layers.ocean -s streams_9000m_100_layers.ocean
#
# srun -n 256 ./ocean_model -n namelist_8000m_50_layers.ocean -s streams_8000m_50_layers.ocean
# srun -n 256 ./ocean_model -n namelist_8000m_100_layers.ocean -s streams_8000m_100_layers.ocean
#
# srun -n 256 ./ocean_model -n namelist_7000m_50_layers.ocean -s streams_7000m_50_layers.ocean
# srun -n 256 ./ocean_model -n namelist_7000m_100_layers.ocean -s streams_7000m_100_layers.ocean
#
# srun -n 256 ./ocean_model -n namelist_6000m_50_layers.ocean -s streams_6000m_50_layers.ocean
# srun -n 256 ./ocean_model -n namelist_6000m_100_layers.ocean -s streams_6000m_100_layers.ocean
#
# srun -n 512 ./ocean_model -n namelist_5000m_50_layers.ocean -s streams_5000m_50_layers.ocean
# srun -n 512 ./ocean_model -n namelist_5000m_100_layers.ocean -s streams_5000m_100_layers.ocean
#
# srun -n 512 ./ocean_model -n namelist_4000m_50_layers.ocean -s streams_4000m_50_layers.ocean
# srun -n 512 ./ocean_model -n namelist_4000m_100_layers.ocean -s streams_4000m_100_layers.ocean
#
# srun -n 512 ./ocean_model -n namelist_3000m_50_layers.ocean -s streams_3000m_50_layers.ocean
# srun -n 512 ./ocean_model -n namelist_3000m_100_layers.ocean -s streams_3000m_100_layers.ocean
#
# srun -n 512 ./ocean_model -n namelist_2000m_50_layers.ocean -s streams_2000m_50_layers.ocean
# srun -n 512 ./ocean_model -n namelist_2000m_100_layers.ocean -s streams_2000m_100_layers.ocean
#
# srun -n 512 ./ocean_model -n namelist_1000m_50_layers.ocean -s streams_1000m_50_layers.ocean
# srun -n 512 ./ocean_model -n namelist_1000m_100_layers.ocean -s streams_1000m_100_layers.ocean
#
# srun -n 512 ./ocean_model -n namelist_900m_50_layers.ocean -s streams_900m_50_layers.ocean
# srun -n 512 ./ocean_model -n namelist_900m_100_layers.ocean -s streams_900m_100_layers.ocean
